# %% [markdown]
# # CF7 — Measurement Theory · Decoherence · Born Rule
#
# - Canon (anchor-only; no duplication): [../../Complete-Formalisms/CF7_Measurement_Theory_Decoherence_Born_Rule.md](../../Complete-Formalisms/CF7_Measurement_Theory_Decoherence_Born_Rule.md)

# %%
# io_paths bootstrap (minimal)
from pathlib import Path
import sys
COMMON = Path.cwd().resolve() / "Derivation" / "code" / "common"
if COMMON.exists() and str(COMMON) not in sys.path:
    sys.path.insert(0, str(COMMON))
try:
    from io_paths import figure_path, log_path  # noqa: F401
except Exception as e:
    print("[warn] io_paths not available:", e)
